# %% [markdown]
# ### AIM
#
# Aim is to find an inexpensive but natural sounding and accurate language model that takes in input from the data sources and transforms it into a script that will be read out for the morning brief.
#
# Let's explore some possible options and consider things like accuracy and cost, and whether features like SSML are supported

# %% [markdown]
# ### SAMPLE RAW DATA INPUT FOR TESTING
#
# SECTION: Calendar Events
# - Event 1: Title: "Weekly Team Sync", Start Time: "2025-04-23T09:00:00", End Time: "2025-04-23T09:30:00", Location: "Zoom link in invite", Description: "Routine check-in with the product team to discuss sprint progress and blockers."
# - Event 2: Title: "Dentist Appointment", Start Time: "2025-04-23T11:45:00", End Time: "2025-04-23T12:15:00", Location: "Pearl Dental, 125 Main Street", Description: "Routine cleaning, check insurance details."
# - Event 3: Title: "Lunch with Sarah", Start Time: "2025-04-23T13:00:00", End Time: "2025-04-23T14:00:00", Location: "The Corner Bistro", Description: "Catch up with Sarah from marketing."
# - Event 4: Title: "Call with Alex (Investor)", Start Time: "2025-04-23T15:30:00", End Time: "2025-04-23T16:00:00", Location: "Phone", Description: "Discuss quarterly numbers and projections."
#
# SECTION: New Emails
# - Email 1: From: "steven.morris@acmeinc.com", Subject: "Re: URGENT – Budget Forecast Update", Received: "2025-04-22T22:19:00", Snippet: "Please review the attached spreadsheet and let me know if the Q2 adjustments look correct. Deadline for feedback is EOD Friday."
# - Email 2: From: "LinkedIn Jobs", Subject: "3 new jobs that match your profile", Received: "2025-04-22T21:07:00", Snippet: "Hi, here are new job listings for Senior Product Manager roles in your area. See recommendations inside."
# - Email 3: From: "Aunt Marie", Subject: "Happy Early Birthday!", Received: "2025-04-22T20:11:00", Snippet: "Just wanted to be the first to say happy birthday for tomorrow! Hope you do something fun."
#
# SECTION: Portfolio Stocks
# - AAPL: Current Price: 174.21 USD, Daily Change: +1.15%
# - MSFT: Current Price: 342.10 USD, Daily Change: -0.23%
# - TSLA: Current Price: 176.87 USD, Daily Change: +2.67%
# - NVDA: Current Price: 905.33 USD, Daily Change: -1.91%
# - VTI: Current Price: 231.22 USD, Daily Change: +0.14%
#
# SECTION: Tasks
# - Task 1: "Finish Q2 report draft", Due: "2025-04-23", Priority: High
# - Task 2: "Book hotel for Boston trip", Due: "2025-04-25", Priority: Medium
# - Task 3: "Respond to legal team feedback on contract edits", Due: "2025-04-24", Priority: High
# - Task 4: "Order more coffee pods", Due: "2025-04-27", Priority: Low
#
# SECTION: Weather Forecast
# - Location: Boston, MA
# - Date: 2025-04-23
# - Forecast: "Morning clouds, clearing by noon. High: 62°F (17°C), Low: 48°F (9°C). Winds NW at 10 to 15 mph. No precipitation expected."
#
# SECTION: News Headlines
# - Headline 1: "Federal Reserve signals no rate hike in upcoming quarter"
# - Headline 2: "Meta announces new AI model to compete with GPT-4"
# - Headline 3: "Severe weather impacts Midwest, over 100,000 without power"
# - Headline 4: "NASA sets Artemis III moon launch window for late 2026"
#
# END OF INPUT

# %% [markdown]
# ### Prompt to Accompany the Input Data
#
# You are a digital personal assistant responsible for generating a natural, conversational morning briefing based on the structured input provided.
#
# Your job is to turn the raw data into a polished, cohesive 5–10 minute spoken script that the user might hear from a smart speaker or assistant.
#
# The tone should be friendly, clear, and engaging — similar to what you'd hear from a high-quality radio host or virtual assistant. Avoid robotic language, overly formal tones, or reading the data verbatim.
#
# Here are the goals:
# - Start with a short greeting and transition into the day's content.
# - Weave together the information from calendar events, emails, stock prices, tasks, weather, and news headlines in a way that flows naturally.
# - Emphasize what's most important first (e.g., urgent emails, upcoming high-priority calendar events).
# - Highlight the weather and news at the end as a "look ahead" for the day.
# - Don't list the data as-is. Use natural language, add transitions, vary sentence structure, and combine details where appropriate.
# - Speak as if you're summarizing for the user — not just reading the raw data.
#
# End the script with a closing remark like "Have a great day" or something similarly warm and brief.
#
# Use this input to generate the briefing:
# [Insert raw data input here]

# %% [markdown]
# ## Model Options
#
# ### Premium High-Performance Cloud Models
#
# ### OpenAI
# - **GPT-4o (Realtime API Text)**
#   • Input: \$5.00 / 1 M tokens
#   • Cached input: \$2.50 / 1 M tokens
#   • Output: \$20.00 / 1 M tokens :contentReference[oaicite:0]{index=0}
# - **GPT-4o mini (Realtime API Text)**
#   • Input: \$0.60 / 1 M tokens
#   • Cached input: \$0.30 / 1 M tokens
#   • Output: \$2.40 / 1 M tokens :contentReference[oaicite:1]{index=1}
# - **GPT-4.1 (Chat Completions API)**
#   • Input: \$2.00 / 1 M tokens
#   • Cached input: \$0.50 / 1 M tokens
#   • Output: \$8.00 / 1 M tokens :contentReference[oaicite:2]{index=2}
# - **GPT-4.1 mini**
#   • Input: \$0.40 / 1 M tokens
#   • Cached input: \$0.10 / 1 M tokens
#   • Output: \$1.60 / 1 M tokens :contentReference[oaicite:3]{index=3}
# - **GPT-4.1 nano**
#   • Input: \$0.10 / 1 M tokens
#   • Cached input: \$0.025 / 1 M tokens
#   • Output: \$0.40 / 1 M tokens :contentReference[oaicite:4]{index=4}
#
# ### Anthropic
# - **Claude 3.7 Sonnet**
#   • Input: \$3.00 / 1 M tokens
#   • Output: \$15.00 / 1 M tokens
#   • Extended “thinking” mode, 128 K context window, excels at coding, reasoning, visual data extraction :contentReference[oaicite:5]{index=5}
#
# ## Mid-Tier Cost-Efficient Models
#
# ### Mistral AI
# - **Mistral Large**
#   • Input: \$4.00 / 1 M tokens
#   • Output: \$12.00 / 1 M tokens
#   • 32 K context window; strong quality-to-cost tradeoff :contentReference[oaicite:6]{index=6}
# - **Mistral Medium**
#   • Input: \$2.70 / 1 M tokens
#   • Output: \$8.10 / 1 M tokens :contentReference[oaicite:7]{index=7}
# - **Mistral Small**
#   • Input: \$1.00 / 1 M tokens
#   • Output: \$3.00 / 1 M tokens :contentReference[oaicite:8]{index=8}
# - **open-mistral-7B** (community-hosted)
#   • Input & Output: \$0.25 / 1 M tokens; self-hosted, zero per-token fees :contentReference[oaicite:9]{index=9}
#
# ## Budget & Open-Source Models
#
# - **Llama 3 (8B & 70B)**
#   • Fully open-source; free weights from Meta for self-hosting; inference costs depend on your own compute infrastructure :contentReference[oaicite:10]{index=10}
# - **Other Tiny / Community Models** (e.g. Gemma 2 variants, Redwood 3B–5B)
#   • Self-hosted, sub-\$1 / 1 M tokens on public quantized runtimes; trade some fluency for minimal cost
#
# ## Emerging End-to-End Audio Models
#
# - **AudioLM**
#   • Research framework for high-fidelity speech & music generation via audio tokens; no commercial pricing yet :contentReference[oaicite:11]{index=11}
# - **AudioPaLM**
#   • Unified text-and-speech LLM supporting speech recognition, generation, and zero-shot translation; research preview :contentReference[oaicite:12]{index=12}

# %% [markdown]
# #### Google Gemini

# %%
from google import genai
import sys
# hack to get around notebook being not in main directory
sys.path.append("..")
from src.utils.config import GEMINI_API_KEY

client = genai.Client(api_key=GEMINI_API_KEY)

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Describe what an SDK is in programming",
)

print(response.text)
# Out:
# An SDK, or **Software Development Kit**, is a collection of software development tools in one installable package. These tools are used to create applications for a specific software package, software framework, hardware platform, operating system, or gaming console.
#
# Think of it like a toolkit for building something specific.  If you want to build a birdhouse, you need a hammer, saw, nails, wood, and instructions.  An SDK provides similar things for software development:
#
# Here's a breakdown of what an SDK typically includes:
#
# *   **Libraries (or APIs):**  These are pre-written blocks of code that perform common tasks, saving developers time and effort. Think of them as pre-fabricated components you can use instead of building everything from scratch.  APIs (Application Programming Interfaces) define how your code can interact with these libraries.
#
# *   **Documentation:**  Comprehensive guides, tutorials, and reference materials that explain how to use the SDK and its various components.  This is crucial for understanding how to use the tools effectively.
#
# *   **Code Samples:**  Working examples of code that demonstrate how to use specific features or functionalities of the SDK.  These help developers learn by example.
#
# *   **Debugging Tools:**  Tools that help developers find and fix errors in their code. This might include debuggers, profilers, and logging tools.
#
# *   **Compilers, Linkers, and Other Build Tools:**  Tools necessary to convert source code into executable programs. (Sometimes)
#
# *   **Emulators/Simulators:**  Software that mimics the behavior of the target platform (e.g., an Android emulator on your computer). This allows developers to test their applications without needing the actual hardware.
#
# **Here's an analogy:**
#
# Imagine you're a chef wanting to create a specific dish (like a fancy cake).
#
# *   The **finished cake** is your application.
# *   The **SDK** is like a specialized baking kit that includes:
#     *   **Pre-made frosting recipes (APIs/Libraries):** Instead of figuring out how to make frosting from scratch, you can use a proven recipe.
#     *   **Detailed instructions (Documentation):** Explains how to use the ingredients and tools.
#     *   **Example cakes (Code Samples):**  Shows different variations of the cake to inspire you.
#     *   **Oven temperature gauge (Debugging Tools):** Helps you ensure your cake is baking correctly.
#
# **Why are SDKs important?**
#
# *   **Reduced Development Time:**  Provides ready-made components, allowing developers to focus on the unique aspects of their applications.
# *   **Simplified Development:**  Abstractions and tools make it easier to interact with complex systems.
# *   **Consistency:**  Encourages developers to build applications that adhere to the standards and best practices of the target platform.
# *   **Access to Features:**  SDKs often provide access to features that would otherwise be difficult or impossible to implement directly.
# *   **Platform Compatibility:**  Helps ensure applications are compatible with the specific operating system, hardware, or framework for which the SDK is designed.
#
# **Examples of SDKs:**
#
# *   **Android SDK:** Used for developing Android applications.
# *   **iOS SDK (formerly iPhone SDK):** Used for developing iOS applications.
# *   **Java Development Kit (JDK):** Used for developing Java applications.
# *   **Microsoft .NET SDK:** Used for developing .NET applications.
# *   **Facebook SDK:** Used for integrating applications with Facebook.
# *   **Unity SDK:** Used for developing games with the Unity game engine.
#
# In summary, an SDK is a comprehensive toolkit that empowers developers to efficiently create applications for a particular platform or environment by providing the necessary tools, libraries, documentation, and support. It's a crucial component in the software development ecosystem.

# %%
from google import genai

client = genai.Client(api_key=GEMINI_API_KEY)
chat = client.chats.create(model="gemini-2.0-flash")

response = chat.send_message("I have 2 dogs in my house.")
print(response.text)

response = chat.send_message("How many paws are in my house?")
print(response.text)

for message in chat.get_history():
    print(f'role - {message.role}',end=": ")
    print(message.parts[0].text)
# Out:
# That's wonderful! Dogs bring so much joy and companionship. Tell me a little more about them! What are their names and breeds? Do they get along well?
#
# If you have two dogs, and each dog has four paws, then there are a total of 8 paws in your house.
#
# role - user: I have 2 dogs in my house.
# role - model: That's wonderful! Dogs bring so much joy and companionship. Tell me a little more about them! What are their names and breeds? Do they get along well?
#
# role - user: How many paws are in my house?
# role - model: If you have two dogs, and each dog has four paws, then there are a total of 8 paws in your house.

# %%
from google import genai
import sys
# hack to get around notebook being not in main directory
sys.path.append("..")
from src.utils.config import GEMINI_API_KEY
from google.genai import types


client = genai.Client(api_key=GEMINI_API_KEY)

input_text = """
You are a digital personal assistant responsible for generating a natural, conversational morning briefing based on the structured input provided.

Your job is to turn the raw data into a polished, cohesive 5–10 minute spoken script that the user might hear from a smart speaker or assistant.

The tone should be friendly, clear, and engaging — similar to what you'd hear from a high-quality radio host or virtual assistant. Avoid robotic language, overly formal tones, or reading the data verbatim.

Here are the goals:
- Start with a short greeting and transition into the day's content.
- Weave together the information from calendar events, emails, stock prices, tasks, weather, and news headlines in a way that flows naturally.
- Emphasize what's most important first (e.g., urgent emails, upcoming high-priority calendar events).
- Highlight the weather and news at the end as a "look ahead" for the day.
- Don't list the data as-is. Use natural language, add transitions, vary sentence structure, and combine details where appropriate.
- Speak as if you're summarizing for the user — not just reading the raw data.

End the script with a closing remark like "Have a great day" or something similarly warm and brief.

Use this input to generate the briefing:


SECTION: Calendar Events
- Event 1: Title: "Weekly Team Sync", Start Time: "2025-04-23T09:00:00", End Time: "2025-04-23T09:30:00", Location: "Zoom link in invite", Description: "Routine check-in with the product team to discuss sprint progress and blockers."
- Event 2: Title: "Dentist Appointment", Start Time: "2025-04-23T11:45:00", End Time: "2025-04-23T12:15:00", Location: "Pearl Dental, 125 Main Street", Description: "Routine cleaning, check insurance details."
- Event 3: Title: "Lunch with Sarah", Start Time: "2025-04-23T13:00:00", End Time: "2025-04-23T14:00:00", Location: "The Corner Bistro", Description: "Catch up with Sarah from marketing."
- Event 4: Title: "Call with Alex (Investor)", Start Time: "2025-04-23T15:30:00", End Time: "2025-04-23T16:00:00", Location: "Phone", Description: "Discuss quarterly numbers and projections."

SECTION: New Emails
- Email 1: From: "steven.morris@acmeinc.com", Subject: "Re: URGENT – Budget Forecast Update", Received: "2025-04-22T22:19:00", Snippet: "Please review the attached spreadsheet and let me know if the Q2 adjustments look correct. Deadline for feedback is EOD Friday."
- Email 2: From: "LinkedIn Jobs", Subject: "3 new jobs that match your profile", Received: "2025-04-22T21:07:00", Snippet: "Hi, here are new job listings for Senior Product Manager roles in your area. See recommendations inside."
- Email 3: From: "Aunt Marie", Subject: "Happy Early Birthday!", Received: "2025-04-22T20:11:00", Snippet: "Just wanted to be the first to say happy birthday for tomorrow! Hope you do something fun."

SECTION: Portfolio Stocks
- AAPL: Current Price: 174.21 USD, Daily Change: +1.15%
- MSFT: Current Price: 342.10 USD, Daily Change: -0.23%
- TSLA: Current Price: 176.87 USD, Daily Change: +2.67%
- NVDA: Current Price: 905.33 USD, Daily Change: -1.91%
- VTI: Current Price: 231.22 USD, Daily Change: +0.14%

SECTION: Tasks
- Task 1: "Finish Q2 report draft", Due: "2025-04-23", Priority: High
- Task 2: "Book hotel for Boston trip", Due: "2025-04-25", Priority: Medium
- Task 3: "Respond to legal team feedback on contract edits", Due: "2025-04-24", Priority: High
- Task 4: "Order more coffee pods", Due: "2025-04-27", Priority: Low

SECTION: Weather Forecast
- Location: Boston, MA
- Date: 2025-04-23
- Forecast: "Morning clouds, clearing by noon. High: 62°F (17°C), Low: 48°F (9°C). Winds NW at 10 to 15 mph. No precipitation expected."

SECTION: News Headlines
- Headline 1: "Federal Reserve signals no rate hike in upcoming quarter"
- Headline 2: "Meta announces new AI model to compete with GPT-4"
- Headline 3: "Severe weather impacts Midwest, over 100,000 without power"
- Headline 4: "NASA sets Artemis III moon launch window for late 2026"

END OF INPUT
"""

response = client.models.generate_content_stream(
    model="gemini-2.5-pro-exp-03-25",
    contents=input_text,
    config=types.GenerateContentConfig(
    temperature=1.5
    )
)

for chunk in response:
    print(chunk.text, end="")
# Out:
# Okay, here is your morning briefing script:
#
# **(Sound of a gentle, brief notification chime)**
#
# "Good morning! Hope you're starting your day well. Let's get you briefed on what's ahead for Wednesday, April 23rd.
#
# First up, diving into your inbox from overnight, there's an email marked **urgent** from Steven Morris regarding the budget forecast update. He sent it late last night and needs your feedback on the Q2 adjustments by the end of the day Friday. So, you'll want to take a look at that attached spreadsheet when you get a moment.
#
# That actually ties into one of your key tasks for today: remember that your high-priority goal is to **finish the Q2 report draft**, as it's due by the end of the day. You also have another high-priority item due *tomorrow*: responding to the legal team's feedback on those contract edits.
#
# Now, looking at your calendar for today:
#
# *   Your morning kicks off at **9:00 AM** with the **Weekly Team Sync**. That's the usual Zoom check-in with the product team on sprint progress. It should wrap up by 9:30 AM.
# *   Then later this morning, you'll need to head out for your **Dentist Appointment**. That's scheduled for **11:45 AM** at Pearl Dental on Main Street. It's just a routine cleaning, but the note says to remember to check your insurance details beforehand. That should finish around 12:15 PM.
# *   Right after that, you've got **Lunch with Sarah** from marketing at The Corner Bistro, starting at **1:00 PM** and going until about 2:00 PM.
# *   And finally, this afternoon at **3:30 PM**, you have that important **call with Alex**, the investor, to discuss the quarterly numbers and projections. That's blocked out for 30 minutes.
#
# A couple of other things on your radar: Don't forget you need to **book that hotel for the Boston trip** – that task is due this Friday. And a lower priority task for whenever you have a spare moment: ordering more coffee pods.
#
# Also in your email, you got the usual job alert from LinkedIn for Senior Product Manager roles, and a very sweet early birthday message from Aunt Marie – she wanted to be the first to wish you well for tomorrow!
#
# Quickly looking at the markets: Yesterday saw a bit of a mix in your portfolio. Apple and Tesla both finished up, with Tesla seeing a nice gain of over 2.5 percent. Microsoft and Nvidia were down slightly, and your VTI index fund saw a small gain.
#
# Alright, let's look outside. Today's weather forecast for Boston calls for some morning clouds, but they should clear up by noon, leading to a pleasant day. Expect a high temperature around 62 degrees Fahrenheit, with a low tonight of 48. Winds will be out of the northwest at 10 to 15 miles per hour, and importantly, no rain is expected today.
#
# And finally, a glance at the news headlines making waves this morning:
# *   The Federal Reserve has indicated they likely won't raise interest rates in the upcoming quarter.
# *   Meta unveiled a new AI model, aiming to compete with existing platforms like GPT-4.
# *   Severe weather continues to impact the Midwest, leaving over 100,000 people without power.
# *   And looking further ahead, NASA has now set the launch window for the Artemis III moon mission for late 2026.
#
# Okay, that covers the key things for your Wednesday! Hope you have a productive and great day!"

# %% [markdown]
# stopSequences: Specifies the set of character sequences (up to 5) that will stop output generation. If specified, the API will stop at the first appearance of a stop_sequence. The stop sequence won't be included as part of the response.
#
# temperature: Controls the randomness of the output. Use higher values for more creative responses, and lower values for more deterministic responses. Values can range from [0.0, 2.0].
#
# maxOutputTokens: Sets the maximum number of tokens to include in a candidate.
#
# topP: Changes how the model selects tokens for output. Tokens are selected from the most to least probable until the sum of their probabilities equals the topP value. The default topP value is 0.95.
#
# topK: Changes how the model selects tokens for output. A topK of 1 means the selected token is the most probable among all the tokens in the model's vocabulary, while a topK of 3 means that the next token is selected from among the 3 most probable using the temperature. Tokens are further filtered based on topP with the final token selected using temperature sampling.
